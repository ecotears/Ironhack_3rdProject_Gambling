# %%
import pandas as pd
df1 = pd.read_excel('/home/ubuntu/Ironhack_all/Ironhack_3rdProject_Gambling/dataset/SQL Test Data.xlsx', 'Account')


df1.head()
# Out:
#     AccountNo   CustId AccountLocation CurrencyCode  DailyDepositLimit  \
# 0  00357DG     3531845             GIB          GBP                  0
# 1  00497XG     4188499             GIB          GBP                  0
# 2  00692VS     4704925             GIB          USD                  0
# 3  00775SM     2815836             GIB          USD                  0
# 4  00C017       889782             GIB          GBP               1500
#
#    StakeScale SourceProd
# 0        1.00         GM
# 1        1.00         SB
# 2        2.00         SB
# 3        1.00         SB
# 4        0.41         XX

# %%
df1_list = []
for i in range(len(df1)):
    temp = (tuple(df1.loc[i]))
    df1_list.append(temp)
    print(temp)


df1_list
# Out:
# ('00357DG   ', 3531845, 'GIB', 'GBP', 0, 1.0, 'GM')
# ('00497XG   ', 4188499, 'GIB', 'GBP', 0, 1.0, 'SB')
# ('00692VS   ', 4704925, 'GIB', 'USD', 0, 2.0, 'SB')
# ('00775SM   ', 2815836, 'GIB', 'USD', 0, 1.0, 'SB')
# ('00C017    ', 889782, 'GIB', 'GBP', 1500, 0.41, 'XX')
# ('00J381    ', 1191874, 'GIB', 'GBP', 500, 8.0, 'XX')
# ('01148BP   ', 1569944, 'GIB', 'GBP', 0, 8.0, 'XX')
# ('01152SJ   ', 1965214, 'GIB', 'USD', 0, 1.0, 'PO')
# ('01196ZZ   ', 3042166, 'GIB', 'EUR', 0, 8.0, 'SB')
# ('01284UW   ', 5694730, 'GIB', 'GBP', 0, 1.0, 'SB')
# [('00357DG   ', 3531845, 'GIB', 'GBP', 0, 1.0, 'GM'),
#  ('00497XG   ', 4188499, 'GIB', 'GBP', 0, 1.0, 'SB'),
#  ('00692VS   ', 4704925, 'GIB', 'USD', 0, 2.0, 'SB'),
#  ('00775SM   ', 2815836, 'GIB', 'USD', 0, 1.0, 'SB'),
#  ('00C017    ', 889782, 'GIB', 'GBP', 1500, 0.41, 'XX'),
#  ('00J381    ', 1191874, 'GIB', 'GBP', 500, 8.0, 'XX'),
#  ('01148BP   ', 1569944, 'GIB', 'GBP', 0, 8.0, 'XX'),
#  ('01152SJ   ', 1965214, 'GIB', 'USD', 0, 1.0, 'PO'),
# ...

# %%
print(tuple(df1.columns))
# Out:
# ('AccountNo', 'CustId', 'AccountLocation', 'CurrencyCode', 'DailyDepositLimit', 'StakeScale', 'SourceProd')

# %%
df2 = pd.read_excel('/home/ubuntu/Ironhack_all/Ironhack_3rdProject_Gambling/dataset/SQL Test Data.xlsx', 'Customer')
df2.head(10)
# Out:
#     CustId AccountLocation Title FirstName  LastName CreateDate CountryCode  \
# 0  4188499             GIB    Mr     Elvis   Presley 2011-11-01          US
# 1  1191874             GIB    Mr       Jim  Morrison 2008-09-19          US
# 2  3042166             GIB    Mr     Keith      Moon 2011-01-11         UK
# 3  5694730             GIB    Mr     James   Hendrix 2012-10-10          US
# 4  4704925             GIB    Mr      Marc     Bolan 2012-03-26         UK
# 5  1569944             GIB  Miss    Janice    Joplin 2009-04-09          US
# 6  3531845             GIB    Mr       Bon     Scott 2011-04-02          AU
# 7  2815836             GIB    Mr     Buddy     Holly 2010-10-17          US
# 8   889782             GIB    Mr       Bob    Marley 2008-01-16         UK
# 9  1965214             GIB    Mr    Sidney   Vicious 2009-12-18         UK
#
#   Language Status DateOfBirth Contact CustomerGroup
# 0       en      A  1948-10-18       Y        Bronze
# ...

# %%
print(tuple(df2.columns))
# Out:
# ('CustId', 'AccountLocation', 'Title', 'FirstName', 'LastName', 'CreateDate', 'CountryCode', 'Language', 'Status', 'DateOfBirth', 'Contact', 'CustomerGroup')

# %%
df2_list = []
for i in range(len(df2)):
    temp2 = (tuple(df2.loc[i]))
    df2_list.append(temp2)


df2_list
# Out:
# [(4188499,
#   'GIB',
#   'Mr',
#   'Elvis',
#   'Presley',
#   Timestamp('2011-11-01 00:00:00'),
#   'US',
#   'en',
#   'A',
#   Timestamp('1948-10-18 00:00:00'),
#   'Y',
#   'Bronze'),
#  (1191874,
#   'GIB',
#   'Mr',
#   'Jim',
#   'Morrison',
#   Timestamp('2008-09-19 00:00:00'),
#   'US',
#   'en',
#   'A',
#   Timestamp('1967-07-27 00:00:00'),
#   'Y',
#   'Gold'),
#  (3042166,
#   'GIB',
#   'Mr',
#   'Keith',
#   'Moon',
#   Timestamp('2011-01-11 00:00:00'),
#   'UK ',
#   'en',
#   'A',
#   Timestamp('1970-07-26 00:00:00'),
#   'Y',
#   'Gold'),
#  (5694730,
#   'GIB',
#   'Mr',
#   'James',
#   'Hendrix',
#   Timestamp('2012-10-10 00:00:00'),
#   'US',
#   'en',
#   'A',
#   Timestamp('1976-04-05 00:00:00'),
#   'N',
#   'Bronze'),
#  (4704925,
#   'GIB',
#   'Mr',
#   'Marc',
#   'Bolan',
#   Timestamp('2012-03-26 00:00:00'),
#   'UK ',
#   'en',
#   'A',
#   Timestamp('1982-03-11 00:00:00'),
#   'Y',
#   'Bronze'),
#  (1569944,
#   'GIB',
#   'Miss',
#   'Janice',
# ...

# %%
df3 = pd.read_excel('/home/ubuntu/Ironhack_all/Ironhack_3rdProject_Gambling/dataset/SQL Test Data.xlsx', 'Betting')

df3.head()

df3['AccountNo'] = df3['AccountNo'].str.strip()

# %%
print(tuple(df3.columns))
# Out:
# ('AccountNo', 'BetDate', 'ClassId', 'CategoryId', 'Source', 'BetCount', 'Bet_Amt', 'Win_Amt', 'Product')

# %%
df3_list = []
for i in range(len(df3)):
    temp3 = (tuple(df3.loc[i]))
    df3_list.append(temp3)


df3_list
# Out:
# [('01196ZZ',
#   Timestamp('2012-11-24 00:00:00'),
#   '22512_XFER',
#   22512,
#   'I',
#   189,
#   29364.0,
#   28947.0,
#   'Vegas'),
#  ('00357DG',
#   Timestamp('2012-11-27 00:00:00'),
#   '22512_XFER',
#   22512,
#   'I',
#   1415,
#   19835.0,
#   18639.15,
#   'Vegas'),
#  ('00357DG',
#   Timestamp('2012-11-24 00:00:00'),
#   '22512_XFER',
#   22512,
#   'I',
#   2026,
#   19280.8,
#   17904.5,
#   'Vegas'),
#  ('01196ZZ',
#   Timestamp('2012-12-19 00:00:00'),
#   '22512_XFER',
#   22512,
#   'I',
#   151,
#   17301.0,
#   16956.0,
#   'Vegas'),
#  ('01284UW',
#   Timestamp('2012-10-21 00:00:00'),
#   46,
#   5,
#   'I',
#   25,
#   16850.0,
#   3319.11,
#   'Sportsbook'),
#  ('00357DG',
#   Timestamp('2012-11-26 00:00:00'),
#   '22512_XFER',
#   22512,
#   'I',
#   1859,
#   16078.5,
#   12299.52,
#   'Vegas'),
#  ('00357DG',
#   Timestamp('2012-11-17 00:00:00'),
#   '22512_XFER',
#   22512,
#   'I',
#   1469,
#   15204.0,
#   14758.8,
#   'Vegas'),
#  ('00357DG',
# ...

# %%
file = open('Betting.txt','w')

for tuple in df3_list:
    file.write(str(tuple) + ',' + '\n')

file.close()

# %%
df4 = pd.read_excel('/home/ubuntu/Ironhack_all/Ironhack_3rdProject_Gambling/dataset/SQL Test Data.xlsx', 'Product')

df4.head()
# Out:
#       CLASSID  CATEGORYID     product  sub_product      description  \
# 0  22522_SALE       22522       Vegas  Vegas Bonus            Vegas
# 1    BETC_RET           0  Sportsbook      Various  Bet Corrections
# 2    BONS_GAM           0       Games  Games Bonus      Games Bonus
# 3   BONS_SPRB           0  Sportsbook     SB Bonus         SB Bonus
# 4   BONS_VEGA           0       Vegas  Vegas Bonus      Vegas Bonus
#
#    bet_or_play
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
df4_list = []
for i in range(len(df4)):
    temp4 = (tuple(df4.loc[i]))
    df4_list.append(temp4)


df4_list
# Out:
# [('22522_SALE', 22522, 'Vegas', 'Vegas Bonus', 'Vegas', 0),
#  ('BETC_RET', 0, 'Sportsbook', 'Various', 'Bet Corrections', 0),
#  ('BONS_GAM', 0, 'Games', 'Games Bonus', 'Games Bonus', 0),
#  ('BONS_SPRB', 0, 'Sportsbook', 'SB Bonus', 'SB Bonus', 0),
#  ('BONS_VEGA', 0, 'Vegas', 'Vegas Bonus', 'Vegas Bonus', 0),
#  ('CSH_PPAL', 0, 'Adjustments', 'Banking Correction', 'PayPal', 0),
#  ('GWIL_SPRT', 0, 'Sportsbook', 'Goodwill Payments', 'Goodwill Payments', 0),
#  (nan, 0, 'Sportsbook', 'Various', 'Manual Bets (Various)', 1),
#  (1, 5, 'Sportsbook', 'Football', 'UK Football', 1),
#  (10, 16, 'Sportsbook', 'Other Sports', 'Boxing', 1),
#  (15, 2, 'Sportsbook', 'Baseball', 'Baseball', 1),
#  (182, 0, 'Games', 'FReactor', 'FReactor', 1),
#  (19, 1, 'Sportsbook', 'American Football', 'American Football', 1),
#  (2, 9, 'Sportsbook', 'Horse Racing', 'Horse Racing - Live', 1),
#  ('22508_RTNS', 22508, 'Bingo', 'Bingo VF', 'Bingo VF Returns', 1),
# ...

# %%
df5 = pd.read_excel('/home/ubuntu/Ironhack_all/Ironhack_3rdProject_Gambling/dataset/SQL Test Data.xlsx', 'Student')

df5.head()
# Out:
#    student_id  student_name           city  school_id  GPA
# 0        1001  Peter Brebec       New York          1  4.0
# 1        1002   John Goorgy  San Francisco          2  3.1
# 2        2003    Brad Smith       New York          3  2.9
# 3        1004  Fabian Johns         Boston          5  2.1
# 4        1005  Brad Cameron       Stanford          1  2.3

# %%
print(tuple(df5.columns))
# Out:
# ('student_id', 'student_name', 'city', 'school_id', 'GPA')

# %%
df5_list = []
for i in range(len(df5)):
    temp5 = (tuple(df5.loc[i]))
    df5_list.append(temp5)


df5_list
# Out:
# [(1001, 'Peter Brebec', 'New York', 1, 4.0),
#  (1002, 'John Goorgy', 'San Francisco', 2, 3.1),
#  (2003, 'Brad Smith', 'New York', 3, 2.9),
#  (1004, 'Fabian Johns', 'Boston', 5, 2.1),
#  (1005, 'Brad Cameron', 'Stanford', 1, 2.3),
#  (1006, 'Geoff Firby', 'Boston', 5, 1.2),
#  (1007, 'Johnny Blue', 'New Haven', 2, 3.8),
#  (1008, 'Johse Brook', 'Miami', 2, 3.4)]

# %%
df6 = pd.read_excel('/home/ubuntu/Ironhack_all/Ironhack_3rdProject_Gambling/dataset/SQL Test Data.xlsx', 'School')

df6.head()
# Out:
#    school_id               school_name           city
# 0          1                  Stanford       Stanford
# 1          2  University of California  San Francisco
# 2          3        Harvard University       New York
# 3          4                       MIT         Boston
# 4          5                      Yale      New Haven

# %%
print(tuple(df6.columns))
# Out:
# ('school_id', 'school_name', 'city')

# %%
df6_list = []
for i in range(len(df6)):
    temp6 = (tuple(df6.loc[i]))
    df6_list.append(temp6)


df6_list
# Out:
# [(1, 'Stanford', 'Stanford'),
#  (2, 'University of California', 'San Francisco'),
#  (3, 'Harvard University', 'New York'),
#  (4, 'MIT', 'Boston'),
#  (5, 'Yale', 'New Haven'),
#  (6, 'University of Westminster', 'London'),
#  (7, 'Corvinus University', 'Budapest')]
